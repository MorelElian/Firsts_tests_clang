# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('addition_papi.csv',sep = ";")

# Grouper les lignes qui ont le même file, size et repeat
df = df.groupby(['file', 'size', 'repeat'], as_index=False).mean()
df
# Out:
#                      file  size  repeat     TOT_CYC  L1_CACHE_MISSES  \
# 0            addition_jit     1      10    33724.25          1524.55
# 1            addition_jit     1      20    33786.75          1518.75
# 2            addition_jit     1      50    34519.45          1526.60
# 3            addition_jit     1     100    34403.65          1523.95
# 4            addition_jit     1    1000    34528.40          1527.20
# ..                    ...   ...     ...         ...              ...
# 149  test_addition_static    64      50    14617.75           257.00
# 150  test_addition_static    64     100    16006.55           255.40
# 151  test_addition_static    64    1000    39529.75           259.00
# 152  test_addition_static    64   10000   274029.75           259.95
# 153  test_addition_static    64  100000  2615001.85           265.65
#
#         TOT_INS
# 0      10043.00
# 1      10043.00
# 2      10043.00
# 3      10043.00
# 4      10043.05
# ..          ...
# ...

# %%
def plot_repeat(df,col):
    for repeat in df['repeat'].unique():
        fig_rep_fix = px.line(df[df['repeat'] == repeat], x='size', y=col, color='file',title = "Evolution of " + col + " for " + str(repeat) + " repetitions")
        fig_rep_fix.show()
    for size in df['size'].unique():
        fig_size_fix = px.line(df[df['size'] == size], x='repeat', y=col, color='file',title = "Evolution of " + col + " for " + str(size) + " size")
        fig_size_fix.show()
plot_repeat(df,'TOT_CYC')
plot_repeat(df,'L1_CACHE_MISSES')
plot_repeat(df,'TOT_INS')

# %%
fig = px.line(df.sort_values('size'), x='size', y='TOT_CYC', color='repeat', line_group='repeat', facet_col='file')
fig.show()
